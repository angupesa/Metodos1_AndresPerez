# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(-5,5,100)
y=np.linspace(-5,5,100)
y1=(2*x1)-2
y2=(1-x1)/2
y3=4-x1

# %%
A=np.array([[2,-1],[1,2],[1,1]])
b=np.array([[2],[1],[4]])

# %%
def GetFit(A,b):
    
    AT = np.dot(A.T,A)
    bT = np.dot(A.T,b)
    
    xsol = np.linalg.solve(AT,bT)
    return xsol

# %%
n=GetFit(A,b)
plt.plot(x1,y1)
plt.plot(x1,y2)
plt.plot(x1,y3)
plt.scatter(n[0],n[1])
n
# Out:
# array([[1.42857143],
#        [0.42857143]])

# %%
def mini(x,y,A,b):
    for i in range(len(x)):
        for j in range(len(y)):
            z=np.array([x[i],y[j]])
            mini= np.linalg.norm((A@z) - b)
    return m

# %%
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111,projection='3d')

ax.plot(x,y,mini(x,y,A,b),color='k',marker='o')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3032\285420357.py in <module>
#       2 ax = fig.add_subplot(111,projection='3d')
#       3
# ----> 4 ax.plot(x,y,mini(x,y,A,b),color='k',marker='o')
#
# ~\AppData\Local\Temp\ipykernel_3032\3012344323.py in mini(x, y, A, b)
#       5             z=np.array([x[i],y[j]])
#       6             mini= np.linalg.norm((A@z) - b)
# ----> 7             m[i].append(mini)
#       8     return m
#
# AttributeError: 'numpy.float64' object has no attribute 'append'

# %%
# Out:
# 26.324893162176366
